# %%
import requests 
import json


resultado = requests.get(url = 'https://dados.fflch.usp.br/api/programas') 
dados = resultado.json()
fll = dados['departamentos'][7]

# %%
resultado = requests.get(url = 'http://127.0.0.1:8000/api/programas/docentes/FLF') 
dados = resultado.json()

# %%
from pandas.core.resample import f

import json
import sys


artigos = []
idLattes_docentes = fll['id_lattes_docentes']
#pegando as informacoes de cada docente
for idLattes in dados:
    idLattes = idLattes['id_lattes']
    url_request = f'http://127.0.0.1:8000/api/programas/docente/{idLattes}'
    lattes = requests.get(url = url_request)
    
    try:
      lattes = lattes.json()
    except:
      print(lattes)
      sys.exit() 
    
    for artigo in lattes['artigos']:
        
        artigos.append({'ISSN': artigo['ISSN'], 'IDIOMA': artigo['IDIOMA'], 'LOCAL-DE-PUBLICACAO': artigo['LOCAL-DE-PUBLICACAO'],
         'PAIS-DE-PUBLICACAO': artigo['PAIS-DE-PUBLICACAO'] })

# %%
import pandas as pd
pd.set_option('display.max_row', None)
df = pd.DataFrame(artigos)
df.loc[df['ISSN'] == '']
# Out:
#     ISSN     IDIOMA  LOCAL-DE-PUBLICACAO PAIS-DE-PUBLICACAO
# 62        Português            São Paulo             Brasil
# 100       Português            São Paulo             Brasil
# 196       Português            São Paulo
# 199       Português            São Paulo
# 226        Espanhol         Buenos Aires
# 229       Português            São Paulo
# 241        Italiano            São Paulo             Brasil
# 245        Italiano            São Paulo             Brasil
# 246        Italiano            São Paulo             Brasil
# 247        Italiano                Japão             Brasil
# 252        Italiano            São Paulo             Brasil
# 253       Português                                  Brasil
# 331       Português            São Paulo             Brasil
# 332       Português            São Paulo
# 333         Francês        Paris - Milão
# 378       Português         Porto Alegre             Brasil
# ...

# %%
url_request = f'http://127.0.0.1:8000/api/programas/docente/0660094592526730'
lattes = requests.get(url = url_request)
    
try:
      lattes = lattes.json()
except:
      print(lattes)
      sys.exit() 
    
print(lattes)
# artigos.append({'nome': lattes['nome'], 'artigos': lattes['artigos']})
# Out:
# {'id_lattes': '0660094592526730', 'orcid': '', 'nome': 'Evani de Carvalho Viotti', 'resumo': 'tem graduação em Direito pela Universidade de São Paulo (1978), graduação em Linguística pela Universidade de São Paulo (1986),  e doutorado em Linguística pela Universidade de São Paulo (1999), feito com bolsa do CNPq. Fez estágios de pós-doutoramento em Linguística na Universidade Estadual de Campinas (2000-2001) e na Universidade de Chicago, nos Estados Unidos, ambos com bolsa da FAPESP. Atualmente é professora doutora da Universidade de São Paulo. Em 2015, foi professora convidada do Centro de Estudos Latino-Americanos e do Departamento de Linguística da Universidade de Chicago, para uma residência Tinker durante a primavera. Tem experiência na área de Teoria e Análise Linguística. Seu interesse principal no momento se insere na área de Epistemologia da Linguística e tem por foco a investigação de fenômenos que emergem do processo semiótico em interações face-a-face.  Em especial, destac
# ...

# %%
artigos
# Out:
# []

# %%
    


import json
print(json.dumps(linhas_pesquisa, sort_keys=True, indent=4))
print(linhas_pesquisa)

# %%
lstDeps = []

# %%
###TESTEEEE

lstDeps = dados[1] # departamentos

linhas_pesquisa = {}
for lst in lstDeps:
  departamento = lst['nome']
  docentes = lst['codpes_docentes']
  linhas_pesquisa[departamento] = {}
  idLattes_docentes = [3752790499157008, 4614382386818949, 9033064139380328]

  ##pegando as informacoes de cada docente
  for idLattes in idLattes_docentes:
    url_request = f'https://dados.fflch.usp.br/api/programas/docente/{idLattes}' 
    lattes = requests.get(url = url_request)
    lattes = lattes.json()
    nome_docente = lattes['nome']
    lnPsq = lattes['linhas_pesquisa']
    linhas_pesquisa[departamento][nome_docente] = lnPsq  


import json
print(json.dumps(linhas_pesquisa, sort_keys=True, indent=4))

print(linhas_pesquisa)
# Out:
# {
#     "Antropologia": {
#         "Ana Claudia Duarte Rocha Marques": [
#             "Poder e Diferen\u00e7a",
#             "Antropologia da Pol\u00edtica"
#         ],
#         "Ana L\u00facia Pastore Schritzmeyer": [
#             "Direitos Humanos; criminalidade urbana",
#             "Pesquisadora associada do GSIADI - Grupo Salamanca de Investigaci\u00f3n de Antropolog\u00eda del Derecho de Iberoamerica",
#             "Antropolog\u00eda"
#         ],
#         "Beatriz Perrone Mois\u00e9s": []
#     },
#     "Ci\u00eancia Pol\u00edtica": {
#         "Ana Claudia Duarte Rocha Marques": [
#             "Poder e Diferen\u00e7a",
#             "Antropologia da Pol\u00edtica"
#         ],
#         "Ana L\u00facia Pastore Schritzmeyer": [
#             "Direitos Humanos; criminalidade urbana",
#             "Pesquisadora associada do GSIADI - Grupo Salamanca de Investigaci\u00f3n de Antropolog\u00eda del Derecho de Iberoamerica",
#             "Antropolog\u00eda"
#         ],
# ...

# %%
import pandas as pd
tabela = pd.DataFrame(dados)
tabela
# Out:
#                                                   0   \
# 0  {'codcur': 8004, 'nomcur': 'Ciência Política',...
# 1  {'sigla': 'FLA', 'codigo': 591, 'nome': 'Antro...
#
#                                                   1   \
# 0  {'codcur': 8001, 'nomcur': 'Ciência Social (An...
# 1  {'sigla': 'FLP', 'codigo': 602, 'nome': 'Ciênc...
#
#                                                   2   \
# 0  {'codcur': 8020, 'nomcur': 'Estudos Lingüístic...
# 1  {'sigla': 'FLF', 'codigo': 594, 'nome': 'Filos...
#
#                                                   3   \
# 0  {'codcur': 8013, 'nomcur': 'Filologia e Língua...
# 1  {'sigla': 'FLH', 'codigo': 598, 'nome': 'Histó...
#
#                                                   4   \
# 0  {'codcur': 8003, 'nomcur': 'Filosofia', 'codar...
# 1  {'sigla': 'FLC', 'codigo': 592, 'nome': 'Letra...
#
#                                                   5   \
# 0  {'codcur': 8006, 'nomcur': 'Geografia (Geograf...
# ...

# %%
from pandas.core.resample import f
#import pandas
lstDeps = dados [1] # secao de departamentos

import json
import sys


linhas_pesquisa = {}

departamento = lstDeps[0]['nome'] #aqui definimos algumas coisas, como pegar o departamento dentros dos dados, no caso 'nome'
idLattes_docentes = lstDeps[0]['codpes_docentes']
linhas_pesquisa[departamento] = {}
#idLattes_docentes = [3752790499157008, 4614382386818949, 9033064139380328,2569898005322201,2112694590578407] #os ids dos docentes estao como numero usp, porem procurar quando resolvido pelo id do lattes

#pegando as informacoes de cada docente
for idLattes in idLattes_docentes:
    url_request = f'https://dados.fflch.usp.br/api/programas/docente/{idLattes}'
    lattes = requests.get(url = url_request)  
    try:
        lattes = lattes.json()
    except:
        print(lattes)
        sys.exit() 
    nome_docente = lattes['nome']
    lnPsq = lattes['linhas_pesquisa']
    linhas_pesquisa[departamento][nome_docente] = lnPsq

import json
print(json.dumps(linhas_pesquisa, sort_keys=True, indent=4))
print(linhas_pesquisa)
# Out:
# {
#     "Antropologia": {
#         "Ana Claudia Duarte Rocha Marques": [
#             "Poder e Diferen\u00e7a",
#             "Antropologia da Pol\u00edtica"
#         ],
#         "Ana L\u00facia Pastore Schritzmeyer": [
#             "Direitos Humanos; criminalidade urbana",
#             "Pesquisadora associada do GSIADI - Grupo Salamanca de Investigaci\u00f3n de Antropolog\u00eda del Derecho de Iberoamerica",
#             "Antropolog\u00eda"
#         ],
#         "Beatriz Perrone Mois\u00e9s": [],
#         "Fernanda Ar\u00eaas Peixoto": [
#             "Hist\u00f3ria das ci\u00eancias sociais no Brasil",
#             "Cultura e pol\u00edtica",
#             "Hist\u00f3ria intelectual",
#             "Cultura e imagin\u00e1rio urbanos",
#             "Antropologia das Formas Expressivas",
#             "Teoria, hist\u00f3ria e m\u00e9todo da Antropologia"
#         ],
#         "Heitor Fr\u00fagoli Junior": [
#             "Estudos da realidade brasileira",
# ...

# %%
dados
# Out:
# [[{'codare': 8131,
#    'codcur': 8004,
#    'discentes': ['6577018114211990',
#     '2188928743489658',
#     '6405720521235233',
#     '2725242292494167',
#     '7243248832921496',
#     '3136409427079289',
#     '6155848104695491',
#     '4225473185834183',
#     '6645436049575503',
#     '5256431615466318',
#     '5171892740964184',
#     '7218535805425100',
#     '3406753169328881',
#     '0185035433307501',
#     '9284399084347419',
#     '7282806021549129',
#     '5686669761066374',
#     '1348622427046443',
#     '0491419892231283',
#     '2072123535482774',
#     '0873670002511125',
#     '0835988052288189',
#     '9098339162553092',
#     '8471200548481969',
#     '3476189886387044',
#     '1939738490716148',
#     '9704227709120729',
#     '9671136971901765',
#     '4621519447109191',
#     '5151147751957592',
#     '0199016826908058',
#     '9722767754436117',
#     '2245533536217475',
#     '8010285764794379',
#     '8269743219142501',
#     '9258695847011883',
# ...

# %%
##Ciência Política

departamento = lstDeps[1]['nome'] #aqui definimos algumas coisas, como pegar o departamento dentros dos dados, no caso 'nome'
idLattes_docentes = lstDeps[1]['codpes_docentes']
linhas_pesquisa[departamento] = {}
#idLattes_docentes = [3752790499157008, 4614382386818949, 9033064139380328,2569898005322201,2112694590578407] #os ids dos docentes estao como numero usp, porem procurar quando resolvido pelo id do lattes

#pegando as informacoes de cada docente
for idLattes in idLattes_docentes:
    url_request = f'https://dados.fflch.usp.br/api/programas/docente/{idLattes}'
    lattes = requests.get(url = url_request)  
    try:
        lattes = lattes.json()
    except:
        print(lattes)
        sys.exit() 
    nome_docente = lattes['nome']
    lnPsq = lattes['linhas_pesquisa']
    linhas_pesquisa[departamento][nome_docente] = lnPsq

import json
print(json.dumps(linhas_pesquisa, sort_keys=True, indent=4))
print(linhas_pesquisa)
# Out:
# {
#     "Antropologia": {
#         "Ana Claudia Duarte Rocha Marques": [
#             "Poder e Diferen\u00e7a",
#             "Antropologia da Pol\u00edtica"
#         ],
#         "Ana L\u00facia Pastore Schritzmeyer": [
#             "Direitos Humanos; criminalidade urbana",
#             "Pesquisadora associada do GSIADI - Grupo Salamanca de Investigaci\u00f3n de Antropolog\u00eda del Derecho de Iberoamerica",
#             "Antropolog\u00eda"
#         ],
#         "Beatriz Perrone Mois\u00e9s": [],
#         "Fernanda Ar\u00eaas Peixoto": [
#             "Hist\u00f3ria das ci\u00eancias sociais no Brasil",
#             "Cultura e pol\u00edtica",
#             "Hist\u00f3ria intelectual",
#             "Cultura e imagin\u00e1rio urbanos",
#             "Antropologia das Formas Expressivas",
#             "Teoria, hist\u00f3ria e m\u00e9todo da Antropologia"
#         ],
#         "Heitor Fr\u00fagoli Junior": [
#             "Estudos da realidade brasileira",
# ...

# %%
departamento = lstDeps[2]['nome'] 
idLattes_docentes = lstDeps[2]['codpes_docentes']
linhas_pesquisa[departamento] = {}
#idLattes_docentes = [3752790499157008, 4614382386818949, 9033064139380328,2569898005322201,2112694590578407] 

#pegando as informacoes de cada docente
for idLattes in idLattes_docentes:
    url_request = f'https://dados.fflch.usp.br/api/programas/docente/{idLattes}'
    lattes = requests.get(url = url_request)  
    try:
        lattes = lattes.json()
    except:
        print(lattes)
        sys.exit() 
    nome_docente = lattes['nome']
    lnPsq = lattes['linhas_pesquisa']
    linhas_pesquisa[departamento][nome_docente] = lnPsq

import json
print(json.dumps(linhas_pesquisa, sort_keys=True, indent=4))
print(linhas_pesquisa)
# Out:
# {
#     "Antropologia": {
#         "Ana L\u00facia Pastore Schritzmeyer": [
#             "Direitos Humanos; criminalidade urbana",
#             "Pesquisadora associada do GSIADI - Grupo Salamanca de Investigaci\u00f3n de Antropolog\u00eda del Derecho de Iberoamerica",
#             "Antropolog\u00eda"
#         ],
#         "Heitor Fr\u00fagoli Junior": [
#             "Estudos da realidade brasileira",
#             "Antropologia urbana"
#         ],
#         "Julio Assis Simoes": [
#             "Marcadores sociais da diferen\u00e7a",
#             "Pol\u00edtica, direitos, viol\u00eancia e homossexualidade",
#             "NUMAS - N\u00facleo de Estudo dos Marcadores Sociais da Difeten\u00e7a",
#             "Rela\u00e7\u00f5es entre ra\u00e7a, sexualidade e g\u00eanero em diferentes contextos locais e nacionais",
#             "Ag\u00eancias p\u00fablicas e seus usu\u00e1rios",
#             "Perspectivas disciplinares e teoria feminista",
#             "Sexualidade",
# ...

# %%
departamento = lstDeps[3]['nome'] 
idLattes_docentes = lstDeps[3]['codpes_docentes']
linhas_pesquisa[departamento] = {}
#idLattes_docentes = [3752790499157008, 4614382386818949, 9033064139380328,2569898005322201,2112694590578407] 

#pegando as informacoes de cada docente
for idLattes in idLattes_docentes:
    url_request = f'https://dados.fflch.usp.br/api/programas/docente/{idLattes}'
    lattes = requests.get(url = url_request)  
    try:
        lattes = lattes.json()
    except:
        print(lattes)
        sys.exit() 
    nome_docente = lattes['nome']
    lnPsq = lattes['linhas_pesquisa']
    linhas_pesquisa[departamento][nome_docente] = lnPsq

import json
print(json.dumps(linhas_pesquisa, sort_keys=True, indent=4))
print(linhas_pesquisa)
# Out:
# {
#     "Antropologia": {
#         "Ana L\u00facia Pastore Schritzmeyer": [
#             "Direitos Humanos; criminalidade urbana",
#             "Pesquisadora associada do GSIADI - Grupo Salamanca de Investigaci\u00f3n de Antropolog\u00eda del Derecho de Iberoamerica",
#             "Antropolog\u00eda"
#         ],
#         "Heitor Fr\u00fagoli Junior": [
#             "Estudos da realidade brasileira",
#             "Antropologia urbana"
#         ],
#         "Julio Assis Simoes": [
#             "Marcadores sociais da diferen\u00e7a",
#             "Pol\u00edtica, direitos, viol\u00eancia e homossexualidade",
#             "NUMAS - N\u00facleo de Estudo dos Marcadores Sociais da Difeten\u00e7a",
#             "Rela\u00e7\u00f5es entre ra\u00e7a, sexualidade e g\u00eanero em diferentes contextos locais e nacionais",
#             "Ag\u00eancias p\u00fablicas e seus usu\u00e1rios",
#             "Perspectivas disciplinares e teoria feminista",
#             "Sexualidade",
# ...

# %%
departamento = lstDeps[4]['nome'] 
idLattes_docentes = lstDeps[4]['codpes_docentes']
linhas_pesquisa[departamento] = {}
#idLattes_docentes = [3752790499157008, 4614382386818949, 9033064139380328,2569898005322201,2112694590578407] 

#pegando as informacoes de cada docente
for idLattes in idLattes_docentes:
    url_request = f'https://dados.fflch.usp.br/api/programas/docente/{idLattes}'
    lattes = requests.get(url = url_request)  
    try:
        lattes = lattes.json()
    except:
        print(lattes)
        sys.exit() 
    nome_docente = lattes['nome']
    lnPsq = lattes['linhas_pesquisa']
    linhas_pesquisa[departamento][nome_docente] = lnPsq

import json
print(json.dumps(linhas_pesquisa, sort_keys=True, indent=4))
print(linhas_pesquisa)
# Out:
# {
#     "Antropologia": {
#         "Ana L\u00facia Pastore Schritzmeyer": [
#             "Direitos Humanos; criminalidade urbana",
#             "Pesquisadora associada do GSIADI - Grupo Salamanca de Investigaci\u00f3n de Antropolog\u00eda del Derecho de Iberoamerica",
#             "Antropolog\u00eda"
#         ],
#         "Heitor Fr\u00fagoli Junior": [
#             "Estudos da realidade brasileira",
#             "Antropologia urbana"
#         ],
#         "Julio Assis Simoes": [
#             "Marcadores sociais da diferen\u00e7a",
#             "Pol\u00edtica, direitos, viol\u00eancia e homossexualidade",
#             "NUMAS - N\u00facleo de Estudo dos Marcadores Sociais da Difeten\u00e7a",
#             "Rela\u00e7\u00f5es entre ra\u00e7a, sexualidade e g\u00eanero em diferentes contextos locais e nacionais",
#             "Ag\u00eancias p\u00fablicas e seus usu\u00e1rios",
#             "Perspectivas disciplinares e teoria feminista",
#             "Sexualidade",
# ...

# %%
departamento = lstDeps[5]['nome'] 
idLattes_docentes = lstDeps[5]['codpes_docentes']
linhas_pesquisa[departamento] = {}
#idLattes_docentes = [3752790499157008, 4614382386818949, 9033064139380328,2569898005322201,2112694590578407] 

#pegando as informacoes de cada docente
for idLattes in idLattes_docentes:
    url_request = f'https://dados.fflch.usp.br/api/programas/docente/{idLattes}'
    lattes = requests.get(url = url_request)  
    try:
        lattes = lattes.json()
    except:
        print(lattes)
        sys.exit() 
    nome_docente = lattes['nome']
    lnPsq = lattes['linhas_pesquisa']
    linhas_pesquisa[departamento][nome_docente] = lnPsq

import json
print(json.dumps(linhas_pesquisa, sort_keys=True, indent=4))
print(linhas_pesquisa)
# Out:
# {
#     "Antropologia": {
#         "Ana L\u00facia Pastore Schritzmeyer": [
#             "Direitos Humanos; criminalidade urbana",
#             "Pesquisadora associada do GSIADI - Grupo Salamanca de Investigaci\u00f3n de Antropolog\u00eda del Derecho de Iberoamerica",
#             "Antropolog\u00eda"
#         ],
#         "Heitor Fr\u00fagoli Junior": [
#             "Estudos da realidade brasileira",
#             "Antropologia urbana"
#         ],
#         "Julio Assis Simoes": [
#             "Marcadores sociais da diferen\u00e7a",
#             "Pol\u00edtica, direitos, viol\u00eancia e homossexualidade",
#             "NUMAS - N\u00facleo de Estudo dos Marcadores Sociais da Difeten\u00e7a",
#             "Rela\u00e7\u00f5es entre ra\u00e7a, sexualidade e g\u00eanero em diferentes contextos locais e nacionais",
#             "Ag\u00eancias p\u00fablicas e seus usu\u00e1rios",
#             "Perspectivas disciplinares e teoria feminista",
#             "Sexualidade",
# ...

# %%
departamento = lstDeps[6]['nome'] 
idLattes_docentes = lstDeps[6]['codpes_docentes']
linhas_pesquisa[departamento] = {}
#idLattes_docentes = [3752790499157008, 4614382386818949, 9033064139380328,2569898005322201,2112694590578407] 

#pegando as informacoes de cada docente
for idLattes in idLattes_docentes:
    url_request = f'https://dados.fflch.usp.br/api/programas/docente/{idLattes}'
    lattes = requests.get(url = url_request)  
    try:
        lattes = lattes.json()
    except:
        print(lattes)
        sys.exit() 
    nome_docente = lattes['nome']
    lnPsq = lattes['linhas_pesquisa']
    linhas_pesquisa[departamento][nome_docente] = lnPsq

import json
print(json.dumps(linhas_pesquisa, sort_keys=True, indent=4))
print(linhas_pesquisa)
# Out:
# {
#     "Antropologia": {
#         "Ana Claudia Duarte Rocha Marques": [
#             "Poder e Diferen\u00e7a",
#             "Antropologia da Pol\u00edtica"
#         ],
#         "Ana L\u00facia Pastore Schritzmeyer": [
#             "Direitos Humanos; criminalidade urbana",
#             "Pesquisadora associada do GSIADI - Grupo Salamanca de Investigaci\u00f3n de Antropolog\u00eda del Derecho de Iberoamerica",
#             "Antropolog\u00eda"
#         ],
#         "Beatriz Perrone Mois\u00e9s": []
#     },
#     "Ci\u00eancia Pol\u00edtica": {
#         "Ana Claudia Duarte Rocha Marques": [
#             "Poder e Diferen\u00e7a",
#             "Antropologia da Pol\u00edtica"
#         ],
#         "Ana L\u00facia Pastore Schritzmeyer": [
#             "Direitos Humanos; criminalidade urbana",
#             "Pesquisadora associada do GSIADI - Grupo Salamanca de Investigaci\u00f3n de Antropolog\u00eda del Derecho de Iberoamerica",
#             "Antropolog\u00eda"
#         ],
# ...

# %%
departamento = lstDeps[7]['nome'] 
idLattes_docentes = lstDeps[7]['codpes_docentes']
linhas_pesquisa[departamento] = {}
#idLattes_docentes = [3752790499157008, 4614382386818949, 9033064139380328,2569898005322201,2112694590578407] #os ids dos docentes estao como numero usp, porem procurar quando resolvido pelo id do lattes

#pegando as informacoes de cada docente
for idLattes in idLattes_docentes:
    url_request = f'https://dados.fflch.usp.br/api/programas/docente/{idLattes}'
    lattes = requests.get(url = url_request)  
    try:
        lattes = lattes.json()
    except:
        print(lattes)
        sys.exit() 
    nome_docente = lattes['nome']
    lnPsq = lattes['linhas_pesquisa']
    linhas_pesquisa[departamento][nome_docente] = lnPsq

import json
print(json.dumps(linhas_pesquisa, sort_keys=True, indent=4))
print(linhas_pesquisa)
# Out:
# {
#     "Antropologia": {
#         "Ana L\u00facia Pastore Schritzmeyer": [
#             "Direitos Humanos; criminalidade urbana",
#             "Pesquisadora associada do GSIADI - Grupo Salamanca de Investigaci\u00f3n de Antropolog\u00eda del Derecho de Iberoamerica",
#             "Antropolog\u00eda"
#         ],
#         "Heitor Fr\u00fagoli Junior": [
#             "Estudos da realidade brasileira",
#             "Antropologia urbana"
#         ],
#         "Julio Assis Simoes": [
#             "Marcadores sociais da diferen\u00e7a",
#             "Pol\u00edtica, direitos, viol\u00eancia e homossexualidade",
#             "NUMAS - N\u00facleo de Estudo dos Marcadores Sociais da Difeten\u00e7a",
#             "Rela\u00e7\u00f5es entre ra\u00e7a, sexualidade e g\u00eanero em diferentes contextos locais e nacionais",
#             "Ag\u00eancias p\u00fablicas e seus usu\u00e1rios",
#             "Perspectivas disciplinares e teoria feminista",
#             "Sexualidade",
# ...

# %%
departamento = lstDeps[8]['nome'] 
idLattes_docentes = lstDeps[8]['codpes_docentes']
linhas_pesquisa[departamento] = {}
#idLattes_docentes = [3752790499157008, 4614382386818949, 9033064139380328,2569898005322201,2112694590578407] #os ids dos docentes estao como numero usp, porem procurar quando resolvido pelo id do lattes

#pegando as informacoes de cada docente
for idLattes in idLattes_docentes:
    url_request = f'https://dados.fflch.usp.br/api/programas/docente/{idLattes}'
    lattes = requests.get(url = url_request)  
    try:
        lattes = lattes.json()
    except:
        print(lattes)
        sys.exit() 
    nome_docente = lattes['nome']
    lnPsq = lattes['linhas_pesquisa']
    linhas_pesquisa[departamento][nome_docente] = lnPsq

import json
print(json.dumps(linhas_pesquisa, sort_keys=True, indent=4))
print(linhas_pesquisa)
# Out:
# {
#     "Antropologia": {
#         "Ana L\u00facia Pastore Schritzmeyer": [
#             "Direitos Humanos; criminalidade urbana",
#             "Pesquisadora associada do GSIADI - Grupo Salamanca de Investigaci\u00f3n de Antropolog\u00eda del Derecho de Iberoamerica",
#             "Antropolog\u00eda"
#         ],
#         "Heitor Fr\u00fagoli Junior": [
#             "Estudos da realidade brasileira",
#             "Antropologia urbana"
#         ],
#         "Julio Assis Simoes": [
#             "Marcadores sociais da diferen\u00e7a",
#             "Pol\u00edtica, direitos, viol\u00eancia e homossexualidade",
#             "NUMAS - N\u00facleo de Estudo dos Marcadores Sociais da Difeten\u00e7a",
#             "Rela\u00e7\u00f5es entre ra\u00e7a, sexualidade e g\u00eanero em diferentes contextos locais e nacionais",
#             "Ag\u00eancias p\u00fablicas e seus usu\u00e1rios",
#             "Perspectivas disciplinares e teoria feminista",
#             "Sexualidade",
# ...

# %%
departamento = lstDeps[9]['nome'] 
idLattes_docentes = lstDeps[9]['codpes_docentes']
linhas_pesquisa[departamento] = {}
#idLattes_docentes = [3752790499157008, 4614382386818949, 9033064139380328,2569898005322201,2112694590578407] #os ids dos docentes estao como numero usp, porem procurar quando resolvido pelo id do lattes

#pegando as informacoes de cada docente
for idLattes in idLattes_docentes:
    url_request = f'https://dados.fflch.usp.br/api/programas/docente/{idLattes}'
    lattes = requests.get(url = url_request)  
    try:
        lattes = lattes.json()
    except:
        print(lattes)
        sys.exit() 
    nome_docente = lattes['nome']
    lnPsq = lattes['linhas_pesquisa']
    linhas_pesquisa[departamento][nome_docente] = lnPsq

import json
print(json.dumps(linhas_pesquisa, sort_keys=True, indent=4))
print(linhas_pesquisa)
# Out:
# {
#     "Antropologia": {
#         "Ana L\u00facia Pastore Schritzmeyer": [
#             "Direitos Humanos; criminalidade urbana",
#             "Pesquisadora associada do GSIADI - Grupo Salamanca de Investigaci\u00f3n de Antropolog\u00eda del Derecho de Iberoamerica",
#             "Antropolog\u00eda"
#         ],
#         "Heitor Fr\u00fagoli Junior": [
#             "Estudos da realidade brasileira",
#             "Antropologia urbana"
#         ],
#         "Julio Assis Simoes": [
#             "Marcadores sociais da diferen\u00e7a",
#             "Pol\u00edtica, direitos, viol\u00eancia e homossexualidade",
#             "NUMAS - N\u00facleo de Estudo dos Marcadores Sociais da Difeten\u00e7a",
#             "Rela\u00e7\u00f5es entre ra\u00e7a, sexualidade e g\u00eanero em diferentes contextos locais e nacionais",
#             "Ag\u00eancias p\u00fablicas e seus usu\u00e1rios",
#             "Perspectivas disciplinares e teoria feminista",
#             "Sexualidade",
# ...

# %%
linhas_pesquisa[departamento]
# Out:
# {'Alfredo Pereira de Queiroz Filho': ['Representação e análise espaço-temporal',
#   'Representação, análise espacial e modelos'],
#  'Andre Roberto Martin': ['Geografia das fronteiras',
#   'Pensamento Geopolítico Brasileiro',
#   'Federalismo e Regionalismo Político no Brasil',
#   'Geopolítica do Poder Mundial',
#   'Integração Regional Latino-americana',
#   'Expressões territoriais contemporâneas',
#   'Geografia Brasileira: História e Política'],
#  'Andreas Attila de Wolinsk Miklos': ['Funcionamento biodinâmico da paisagem',
#   'Funcionamento hidrobiogeoquímico de bacias hidrográficas',
#   'Agroecologia',
#   'Agricultura sustentável, ecológica e orgânica',
#   'Pedologia, Pedobiologia e Análise trutural da Cobertura Pedológica',
#   'Agricultura Biodinâmica',
#   'Percepção da Paisagem, Fenomelogia de Goethe e Antroposofia'],
#  'Anselmo Alfredo': ['Modernização e Industrialização Brasileira: estudos e debates na Geografia',
#   'A Questão Agrária no Brasil',
# ...

# %%
departamento = lstDeps[10]['nome'] 
idLattes_docentes = lstDeps[10]['codpes_docentes']
linhas_pesquisa[departamento] = {}
#idLattes_docentes = [3752790499157008, 4614382386818949, 9033064139380328,2569898005322201,2112694590578407] #os ids dos docentes estao como numero usp, porem procurar quando resolvido pelo id do lattes

#pegando as informacoes de cada docente
for idLattes in idLattes_docentes:
    url_request = f'https://dados.fflch.usp.br/api/programas/docente/{idLattes}'
    lattes = requests.get(url = url_request)  
    try:
        lattes = lattes.json()
    except:
        print(lattes)
        sys.exit() 
    nome_docente = lattes['nome']
    lnPsq = lattes['linhas_pesquisa']
    linhas_pesquisa[departamento][nome_docente] = lnPsq

import json
print(json.dumps(linhas_pesquisa, sort_keys=True, indent=4))
print(linhas_pesquisa)
# Out:
# {
#     "Antropologia": {
#         "Ana L\u00facia Pastore Schritzmeyer": [
#             "Direitos Humanos; criminalidade urbana",
#             "Pesquisadora associada do GSIADI - Grupo Salamanca de Investigaci\u00f3n de Antropolog\u00eda del Derecho de Iberoamerica",
#             "Antropolog\u00eda"
#         ],
#         "Julio Assis Simoes": [
#             "Marcadores sociais da diferen\u00e7a",
#             "Pol\u00edtica, direitos, viol\u00eancia e homossexualidade",
#             "NUMAS - N\u00facleo de Estudo dos Marcadores Sociais da Difeten\u00e7a",
#             "Rela\u00e7\u00f5es entre ra\u00e7a, sexualidade e g\u00eanero em diferentes contextos locais e nacionais",
#             "Ag\u00eancias p\u00fablicas e seus usu\u00e1rios",
#             "Perspectivas disciplinares e teoria feminista",
#             "Sexualidade",
#             "G\u00eanero e Envelhecimento"
#         ]
#     },
#     "Geografia": {
#         "Alfredo Pereira de Queiroz Filho": [
# ...

# %%
json_object = json.dumps(linhas_pesquisa, indent = 4) 
print(json_object)
# Out:
# {
#     "Antropologia": {
#         "Ana L\u00facia Pastore Schritzmeyer": [
#             "Direitos Humanos; criminalidade urbana",
#             "Pesquisadora associada do GSIADI - Grupo Salamanca de Investigaci\u00f3n de Antropolog\u00eda del Derecho de Iberoamerica",
#             "Antropolog\u00eda"
#         ],
#         "Julio Assis Simoes": [
#             "Marcadores sociais da diferen\u00e7a",
#             "Pol\u00edtica, direitos, viol\u00eancia e homossexualidade",
#             "NUMAS - N\u00facleo de Estudo dos Marcadores Sociais da Difeten\u00e7a",
#             "Rela\u00e7\u00f5es entre ra\u00e7a, sexualidade e g\u00eanero em diferentes contextos locais e nacionais",
#             "Ag\u00eancias p\u00fablicas e seus usu\u00e1rios",
#             "Perspectivas disciplinares e teoria feminista",
#             "Sexualidade",
#             "G\u00eanero e Envelhecimento"
#         ],
#         "Heitor Fr\u00fagoli Junior": [
# ...

# %%
with open('linhas_pesquisa.json', 'w') as f:
    json.dump(linhas_pesquisa, f)

# %%
with open('linhas_pesquisa.json') as d:
   lpJson = json.load(d)

# %%
lpJson.keys()
# Out:
# dict_keys(['Antropologia'])

# %%
lpJson['Antropologia'] ##site desse dept tem as linhas de pesquisa, mas não os docentes
# Out:
# {'Ana Claudia Duarte Rocha Marques': ['Poder e Diferença',
#   'Antropologia da Política'],
#  'Ana Lúcia Pastore Schritzmeyer': ['Direitos Humanos; criminalidade urbana',
#   'Pesquisadora associada do GSIADI - Grupo Salamanca de Investigación de Antropología del Derecho de Iberoamerica',
#   'Antropología'],
#  'Beatriz Perrone Moisés': [],
#  'Fernanda Arêas Peixoto': ['História das ciências sociais no Brasil',
#   'Cultura e política',
#   'História intelectual',
#   'Cultura e imaginário urbanos',
#   'Antropologia das Formas Expressivas',
#   'Teoria, história e método da Antropologia'],
#  'Heitor Frúgoli Junior': ['Estudos da realidade brasileira',
#   'Antropologia urbana'],
#  'Heloisa Buarque de Almeida': ['Mídia',
#   'Marcadores sociais da diferença',
#   'Mídia',
#   'Gênero',
#   'Cultura e Política'],
#  'João Felipe Ferreira Gonçalves': [],
#  'Julio Assis Simoes': ['Marcadores sociais da diferença',
#   'Política, direitos, violência e homossexualidade',
# ...

# %%
lpJson['Antropologia']
linhas_antr = [];
for prof in lpJson['Antropologia']:
  linhas_antr += lpJson['Antropologia'][prof]

# %%
import pandas as pd 
tabela = pd.DataFrame(linhas_antr)
tabela
# Out:
#                                                     0
# 0              Direitos Humanos; criminalidade urbana
# 1   Pesquisadora associada do GSIADI - Grupo Salam...
# 2                                        Antropología
# 3                     Marcadores sociais da diferença
# 4    Política, direitos, violência e homossexualidade
# 5   NUMAS - Núcleo de Estudo dos Marcadores Sociai...
# 6   Relações entre raça, sexualidade e gênero em d...
# 7                   Agências públicas e seus usuários
# 8       Perspectivas disciplinares e teoria feminista
# 9                                         Sexualidade
# 10                            Gênero e Envelhecimento
# 11                    Estudos da realidade brasileira
# 12                                Antropologia urbana
# 13                                              Mídia
# 14                    Marcadores sociais da diferença
# 15                                              Mídia
# ...

# %%
lpJson['Geografia']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-39-42f42db605a4> in <module>()
# ----> 1 lpJson['Geografia']
#
# KeyError: 'Geografia'

# %%
lpJson['Sociologia']
linhas_socio = [];
for prof in lpJson['Sociologia']:
  linhas_socio += lpJson['Sociologia'][prof]
import pandas as pd
tabela = pd.DataFrame(linhas_socio)
tabela
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-37-02c2e7ab54f5> in <module>()
# ----> 1 lpJson['Sociologia']
#       2 linhas_socio = [];
#       3 for prof in lpJson['Sociologia']:
#       4   linhas_socio += lpJson['Sociologia'][prof]
#       5 import pandas as pd
#
# KeyError: 'Sociologia'
